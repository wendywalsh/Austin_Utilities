# %%
import pandas as pd
import numpy as np
import os

# %%
commercial_water_consumption = pd.read_csv('Austin_Water_-_Commercial_Water_Consumption.csv')
commercial_water_consumption.head()
# Out:
#    YearMonth  PostalCode            CustomerClass  TotalGallons
# 0     201201       78613  Irrigation - Commercial        855400
# 1     201201       78613               Commercial       2880800
# 2     201201       78617     Austin Water Utility        438700
# 3     201201       78617           City of Austin       6500300
# 4     201201       78617               Commercial       9120500

# %%
residential_water_consumption = pd.read_csv('Austin_Water_-_Residential_Water_Consumption.csv')
residential_water_consumption.head()
# Out:
#    YearMonth  PostalCode              CustomerClass  TotalGallons
# 0     201201       78613               Multi-Family         23000
# 1     201201       78613  Irrigation - Multi-Family         11000
# 2     201201       78617               Multi-Family       2477000
# 3     201201       78617                Residential      19962500
# 4     201201       78652   Irrigation - Residential         38500

# %%
# reformat date 
residential_water_consumption['YearMonth'] = pd.to_datetime(residential_water_consumption['YearMonth'], format='%Y%m')
residential_water_consumption
# Out:
#        YearMonth  PostalCode              CustomerClass  TotalGallons
# 0     2012-01-01       78613               Multi-Family         23000
# 1     2012-01-01       78613  Irrigation - Multi-Family         11000
# 2     2012-01-01       78617               Multi-Family       2477000
# 3     2012-01-01       78617                Residential      19962500
# 4     2012-01-01       78652   Irrigation - Residential         38500
# 5     2012-01-01       78652                Residential        632300
# 6     2012-01-01       78652               Multi-Family        116900
# 7     2012-01-01       78653               Multi-Family        194500
# 8     2012-01-01       78653                Residential       2577800
# 9     2012-01-01       78660                Residential       7226400
# 10    2012-01-01       78660               Multi-Family       3805800
# 11    2012-01-01       78701  Irrigation - Multi-Family        182600
# ...

# %%
# Union commercial and residential data
dataframes = [commercial_water_consumption, residential_water_consumption]
compiled_resident_commercial = pd.concat(dataframes)
compiled_resident_commercial.head()
# Out:
#   YearMonth  PostalCode            CustomerClass  TotalGallons
# 0    201201       78613  Irrigation - Commercial        855400
# 1    201201       78613               Commercial       2880800
# 2    201201       78617     Austin Water Utility        438700
# 3    201201       78617           City of Austin       6500300
# 4    201201       78617               Commercial       9120500

# %%
compiled_resident_commercial['YearMonth'] = pd.to_datetime(compiled_resident_commercial['YearMonth'], format='%Y%m')
compiled_resident_commercial
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     443             try:
# --> 444                 values, tz = tslib.datetime_to_datetime64(arg)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64 (pandas/_libs/tslib.c:33275)()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-1a86fadb1962> in <module>()
# ----> 1 compiled_resident_commercial['YearMonth'] = pd.to_datetime(compiled_resident_commercial['YearMonth'], format='%Y%m')
#       2 compiled_resident_commercial
#
# ...

# %%
water_pumped_per_capita = pd.read_csv('Austin_Water_-_Gallons_of_Water_Pumped_per_Capita.csv')
water_pumped_per_capita
# Out:
#     FiscalYear      Pumpage  WaterService_Population  \
# 0         1995  39485284858                   630997
# 1         1996  45818995265                   649660
# 2         1997  42802218907                   668876
# 3         1998  46668518691                   688660
# 4         1999  46604542024                   709029
# 5         2000  52326072112                   738229
# 6         2001  50184846041                   754470
# 7         2002  50883135913                   767296
# 8         2003  51110853373                   774969
# 9         2004  48468969212                   786594
# 10        2005  51373931437                   799966
# 11        2006  56602598744                   815085
# 12        2007  45867662567                   834647
# 13        2008  53066075799                   853843
# 14        2009  53331329600                   872628
# 15        2010  43827360000                   875936
# 16        2011  52823662000                   891997
# ...

# %%
gallons_water_treated = pd.read_csv('Austin_Water_-_Gallons_of_Water_and_Wastewater_Treated.csv')
gallons_water_treated
# Out:
#      Year Month                    Plant TypeofWater  MGTreated
# 0    2011   Oct                    Davis       Water    2512.94
# 1    2011   Oct                  Ullrich       Water    2129.12
# 2    2011   Oct  Water Treatment Plant 4       Water        NaN
# 3    2011   Nov                    Davis       Water    2405.53
# 4    2011   Nov                  Ullrich       Water    1387.45
# 5    2011   Nov  Water Treatment Plant 4       Water        NaN
# 6    2011   Dec                    Davis       Water    1646.50
# 7    2011   Dec                  Ullrich       Water    1558.34
# 8    2011   Dec  Water Treatment Plant 4       Water        NaN
# 9    2012   Jan                    Davis       Water    1480.63
# 10   2012   Jan                  Ullrich       Water    1880.21
# 11   2012   Jan  Water Treatment Plant 4       Water        NaN
# 12   2012   Feb                    Davis       Water    1095.40
# 13   2012   Feb                  Ullrich       Water    1913.29
# ...
